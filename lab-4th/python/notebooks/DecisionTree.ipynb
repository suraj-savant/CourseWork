# %%
### To view iris dataset uncomment following code 
import seaborn as ses
data = ses.load_dataset("iris")
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
## Import required libraries and load dataset
from sklearn.datasets import load_iris
from sklearn import tree

iris = load_iris()
X, y = iris.data, iris.target

# %%
### train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=42)

# %%
# Uncomment lines to see training data and op
print("Train dataset")
for i in range(10) :
    print(f"{X_train[i]} : {iris.target_names[y_train[i]]}")

print("Test dataset")
for i in range(10) :
    print(f"{X_test[i]} : {iris.target_names[y_test[i]]}")
# Out:
# Train dataset
# [5.7 2.9 4.2 1.3] : versicolor
# [7.6 3.  6.6 2.1] : virginica
# [5.6 3.  4.5 1.5] : versicolor
# [5.1 3.5 1.4 0.2] : setosa
# [7.7 2.8 6.7 2. ] : virginica
# [5.8 2.7 4.1 1. ] : versicolor
# [5.2 3.4 1.4 0.2] : setosa
# [5.  3.5 1.3 0.3] : setosa
# [5.1 3.8 1.9 0.4] : setosa
# [5.  2.  3.5 1. ] : versicolor
# Test dataset
# [6.1 2.8 4.7 1.2] : versicolor
# [5.7 3.8 1.7 0.3] : setosa
# [7.7 2.6 6.9 2.3] : virginica
# [6.  2.9 4.5 1.5] : versicolor
# [6.8 2.8 4.8 1.4] : versicolor
# [5.4 3.4 1.5 0.4] : setosa
# [5.6 2.9 3.6 1.3] : versicolor
# [6.9 3.1 5.1 2.3] : virginica
# [6.2 2.2 4.5 1.5] : versicolor
# [5.8 2.7 3.9 1.2] : versicolor

# %%
# Create a decision tree and fit data into it
clf = tree.DecisionTreeClassifier(criterion="entropy")
clf = clf.fit(X_train, y_train)

# %%
# Calculate the accuracy score
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy*100)
# Out:
# Accuracy:  98.0

# %%
# predict the ouput based on parameters
selpal_len, sepal_width = float(input("Enter sepal length: ")),float(input("Enter sepal width : "))
petal_len, petal_width = float(input("Enter petal length : ")),float(input("Enter petal width : "))
pred = clf.predict([[selpal_len, sepal_width, petal_len, petal_width]])
print("The flower type is ", end
# Out:
#   File "C:\Users\suraj\AppData\Local\Temp\ipykernel_1868\1301264751.py", line 6
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
tree.plot_tree(clf, filled = True)
# Out:
# [Text(0.4444444444444444, 0.9285714285714286, 'X[3] <= 0.8\nentropy = 1.583\nsamples = 100\nvalue = [31, 35, 34]'),
#  Text(0.3333333333333333, 0.7857142857142857, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0, 0]'),
#  Text(0.5555555555555556, 0.7857142857142857, 'X[3] <= 1.75\nentropy = 1.0\nsamples = 69\nvalue = [0, 35, 34]'),
#  Text(0.3333333333333333, 0.6428571428571429, 'X[2] <= 5.35\nentropy = 0.485\nsamples = 38\nvalue = [0, 34, 4]'),
#  Text(0.2222222222222222, 0.5, 'X[3] <= 1.45\nentropy = 0.31\nsamples = 36\nvalue = [0, 34, 2]'),
#  Text(0.1111111111111111, 0.35714285714285715, 'entropy = 0.0\nsamples = 26\nvalue = [0, 26, 0]'),
#  Text(0.3333333333333333, 0.35714285714285715, 'X[1] <= 2.6\nentropy = 0.722\nsamples = 10\nvalue = [0, 8, 2]'),
#  Text(0.2222222222222222, 0.21428571428571427, 'X[0] <= 6.15\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.1111111111111111, 0.07142857142857142, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1868\35154765.py in <module>
# ----> 1 clf.score()
#
# TypeError: score() missing 2 required positional arguments: 'X' and 'y'
